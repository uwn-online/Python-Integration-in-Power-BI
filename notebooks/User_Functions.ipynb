# %%
#Create defined functions

def function():
    print("Hello World")
    print("Welcome to my world")
#call the function
function()
# Out:
# Hello World
# Welcome to my world

# %%
#Function with arguments
def greetings(x):
    print(x)
greetings("Wassup")
# Out:
# Wassup

# %%
def greetings(x):
    return(x)*10
greetings(" Wassup dude ")
# Out:
# ' Wassup dude  Wassup dude  Wassup dude  Wassup dude  Wassup dude  Wassup dude  Wassup dude  Wassup dude  Wassup dude  Wassup dude '

# %%
def formula(x,y):
    print(x*2+y+1)
formula(10, 4)
# Out:
# 25

# %%
#Conditional function

name1 = "Jude"
salary1 = 5000
sideincome1 = 2000
expenses1 = 1300

name2 = "Joe"
salary2 = 4000
sideincome2 = 770
expenses2 = 1000

name3 = "Jim"
salary3 = 2000
sideincome3 = 500
expenses3 = 200

# %%
def is_approved(name, salary, sideincome, expenses):
    yearly_total = salary*12+sideincome*12-expenses*12
    return name, yearly_total

# %%
is_approved(name2, salary2, sideincome2, expenses2)
# Out:
# ('Joe', 45240)

# %%
def is_approved(name, salary, sideincome, expenses):
    yearly_total = salary*12+sideincome*12-expenses*12
    if yearly_total>40000:
        return name + ", you are approved"
    else:
        return name + ", Come back next year"

# %%
result1=is_approved(name1, salary1, sideincome1, expenses1)
result2=is_approved(name2, salary2, sideincome2, expenses2)
result3=is_approved(name3, salary3, sideincome3, expenses3)

# %%
print(result1)
print(result2)
print(result3)
# Out:
# Jude, you are approved
# Joe, you are approved
# Jim, Come back next year

# %% [markdown]
# ### Cleaning functions for datasets

# %%
def clean_text(x):
    x = x.replace('$', '')
    x = x.replace('-', '')
    x = x.replace(',', '')
    x = x.replace(' ', '')
    x = pd.to_numeric(x)
    return x

# %% [markdown]
# ### Lists and Loops

# %%
my_list = [1,2,3,4]
my_list
